# %% [markdown]
# # 1.Write a Program that check whether a number is positive,Negative or Zero

# %%
n=int(input())
if n>0:
    print("Positive")
elif n<0:
    print("Negative")
else:
    print("Zero")
# Out:
# Positive

# %% [markdown]
# # 2.Check whether a person is eligible to vote.

# %%
age=int(input())
if age>=18:
    print("Eligible for vote")
else:
    print("Not Eligible for Vote")
# Out:
# Eligible for vote

# %% [markdown]
# # 3.Write a Python program to check whether a number is Even or Odd.

# %%
n=int(input())
if n%2==0:
    print("Even")
else:
    print("Odd")
# Out:
# Odd

# %% [markdown]
# # 4.Write a Python program to find the largest of two numbers.

# %%
a=int(input())
b=int(input())
if a>b:
    print(a)
elif b>a:
    print(b)
else:
    print(a,b)
# Out:
# 10 10

# %% [markdown]
# # 5.Write a Python program to find the largest of three numbers.

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a == b == c:
    print("All numbers are equal")
elif a >= b and a >= c:
    print("Largest:", a)
elif b >= a and b >= c:
    print("Largest:", b)
else:
    print("Largest:", c)
# Out:
# Largest: 30

# %% [markdown]
# # 6.Write a Python program to check whether a year is a Leap Year.

# %%
year=int(input())
if (year%4==0 and year%100!=0) or year%400==0:
    print("leap Year")
else:
    print("Not a leap year")
# Out:
# leap Year

# %% [markdown]
# # 7.Write a Python program to calculate a student's grade based on marks.
#
# Grade Criteria
# Marks	Grade
# 90–100	A
# 75–89	B
# 50–74	C
# 35–49	D
# Below 35	Fail

# %%
marks=int(input())
if marks<0 or  marks>100:
    print("Invalid Marks")
elif marks>=90 and marks<=100:
    print("A")
elif marks>=75 and marks<=89:
    print("B")
elif marks>=50 and marks<=74:
    print("C")
elif marks>=35 and marks<=49:
    print("D")
else:
    print("fail")
# Out:
# fail

# %% [markdown]
# # 8.Write a Python program to check whether a person is eligible for a loan.
#
# Conditions
#
# A person is eligible only if:
#
# Age is 21 or above, AND
# Salary is 25,000 or more.
#
# Otherwise, print Not Eligible.

# %%
age=int(input())
salary=int(input())
if age>=21 and salary>=25000:
    print("Eligible for Loan")
else:
    print("Not Eligible")
# Out:
# Not Eligible

# %% [markdown]
# # 9.Write a Python program to create a Simple Calculator.
#
# Requirements
# Take two numbers as input.
# Take an operator as input (+, -, *, /).
# Perform the corresponding operation using if-elif-else.
# If the operator is invalid, print:

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
operator = input("Enter operator (+, -, *, /): ")

if operator == "+":
    print(num1 + num2)
elif operator == "-":
    print(num1 - num2)
elif operator == "*":
    print(num1 * num2)
elif operator == "/":
    if num2 != 0:
        print(num1 / num2)
    else:
        print("Cannot divide by zero")
else:
    print("Invalid Operator")
# Out:
# 27.0
