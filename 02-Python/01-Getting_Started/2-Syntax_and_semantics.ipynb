# %% [markdown]
# # Syntax:
#
# Syntax is the set of rules that defines how Python code should be written.
#
# If the syntax is incorrect, Python cannot understand the code and raises a SyntaxError.

# %%
print("hello")
# Out:
# hello

# %%
#Invalid syntax
print("hello"
# Out:
#   Cell In[2], line 1
#     print("hello"
#                  ^
# SyntaxError: incomplete input

# %% [markdown]
# # semantics:
#
# Semantics refers to the meaning or logic of the code.
#
# Even if the syntax is correct, the program can still produce the wrong result if the logic is incorrect.

# %%
a=10
b=20
print(a+b)
# Out:
# 30

# %% [markdown]
# # Comments
#
# A comment is text in your code that is ignored by Python.
#
# Comments are written for humans, not for the computer.
#
# ## Why do we use comments?
#
# - Explain what the code does.
# - Make the code easier to understand.
# - Leave notes for ourselves or teammates.
# - Temporarily disable a line of code while testing.
#
# ## Single-Line Comment
#
# ```python
# # This is a single-line comment
# print("Hello")
# ```
#
# ## Multi-Line Comment
#
# ```python
# """
# This is a
# multi-line comment
# """
#
# print("Hello")
# ```

# %%
#This is a single line comment
print("Praveen")
# Out:
# Praveen

# %%
"""
This is a 
multiline comment
"""

print("Hello, World!")
# Out:
# Hello, World!

# %%
##Line Continuation
sum=1+2+3+4+5+6+\
5+6+8+10
print(sum)
# Out:
# 50

# %% [markdown]
# # Indentation
#
# ## Definition
#
# Indentation means leaving spaces (or a tab) at the beginning of a line of code to show that it belongs to a block.
#
# Python uses indentation instead of { } (curly braces) like C, C++, or Java.
#
# ## Why is indentation important?
#
# Python uses indentation to determine:
#
# Which statements belong together.
# Which code should execute under conditions, loops, functions, etc.
#
# If the indentation is incorrect, Python raises an IndentationError.

# %%
#indentation example
age=20
if age>=18:
    print("Eligible for vote")
print("Program finished")
# Out:
# Eligible for vote
# Program finished

# %%
#Indentaion Error
age=20
if age>=18:
print("Eligible for vote")
print("Program finished")
# Out:
#   Cell In[7], line 4
#     print("Eligible for vote")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 3

# %%
marks = 75

if marks >= 35:
    print("Pass")
    print("Congratulations!")
# Out:
# Pass
# Congratulations!
